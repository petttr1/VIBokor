# %% [markdown]
# # Wikipedia Alternate Titles - Evaluation

# %% [markdown]
# ## Peter Bokor

# %%
import json
import requests
import random
import re 
import numpy as np
from difflib import SequenceMatcher
import pandas as pd
import unidecode

# %%
def parse_response(resp):
    """function to parse the web search response and extract found titles"""
    # parse response text as dict 
    res_dict = json.loads(resp.text)
    # extract titles
    titles = [r['title'] for r in res_dict['value']]
    return titles

# %%
def string_similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
with open('indices/enwiki_index.json', encoding='utf8') as json_file:
    index = json.load(json_file)

# %%
def choose_alt_and_title(index):
    try:
        title = random.choice(list(filter(lambda k: len(k.split()) == 1, index.keys())))
        alt = random.choice(list(filter(lambda v: len(v.split()) == 1, index[title])))
        return alt, title
    except:
        return choose_alt_and_title(index)

# %% [markdown]
# We load the index created into memory. English wiki will be used for the evaluation.

# %%
# prepare url and headers
url = "https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/Search/WebSearchAPI"
headers = {
    'x-rapidapi-host': "contextualwebsearch-websearch-v1.p.rapidapi.com",
    'x-rapidapi-key': "9805ad717fmsh887356c31eef1c7p1d4dfejsn31827afa9324"
    }
main_titles, alt_titles, found, matches, similarities = [], [], [], [], []
for i in range(100):
    # select main and alt title at random from index
    title, alt = random.choice(list(index.items()))
    alt = random.choice(alt)
    # preprocess the titles (Disambiguations and simialr WIKI stuff may be present)
    title, alt = re.split('[#:(]', title)[0], re.split('[#:(]', alt)[0]
    # query the alt title in web search
    querystring = {"pageNumber":"1","q":alt,"autoCorrect":"false","pageSize":"50"}
    try:
        response = requests.request("GET", url, headers=headers, params=querystring)
        # parse found titles
        found_titles = parse_response(response)
        # Title found or not?
        title_found = True in [title in t for t in found_titles]
        #calculate titles similarity
        max_similarity = max(np.array([string_similar(t, title) for t in found_titles]))

        main_titles.append(title)
        alt_titles.append(alt)
        found.append(found_titles)
        matches.append(title_found)
        similarities.append(max_similarity)
    except:
        continue

# %% [markdown]
# Above we select 100 records from the index and search for them using Web Search API. We parse and save the results for later evaluation.

# %%
matches = np.array(matches)
accuracy = len(matches[matches == True]) / len(matches)
accuracy
# Out:
# 0.550561797752809

# %% [markdown]
# We see that the accuracy is somewhat poor.

# %%
sum(similarities) / len(similarities)
# Out:
# 0.5382991291393447

# %% [markdown]
# We can see that the result seem underwhelming. Looking at a few examples (below) we can notice though, that the results produced by the search API are perhaps not what we'd expect.
#
# Another problem we have to deal with is 2 word phrases as a alt. title. Using string similarity the way we did above may not be the best solution as the search results may be longer than the phrase we search for and we immediately get biased results.
#
# We can not solve the problem with API (we could find a better one, but let's presume we have the best one there is). We can deal with the other problem however. We could calculate similarity in all subsets of each search result and consider only the highest scoring. For example, for a 2 word alternate title, we could match the 2 words with every word subset of every result with the length of 2. This would take a lot of time.
#
# A better solution seems to be using just 1 word alternate titles and considering the word to be a match if the word is present in any of the results returned by our search.

# %%
df = pd.DataFrame({'title': main_titles, 'alt_title': alt_titles, 'found': found, 'match': matches})
df
# Out:
#               title               alt_title  \
# 0     Kischinskinia  Kischinskinia scandens
# 1              Phet                   Phet
# 2            Alinja                  Əlincə
# 3            Conboy                 Conboy
# 4              Lat.                   Lat.
# ..              ...                     ...
# 84          Beignet                 Beneigh
# 85          Tarring                Tarring
# 86           Mmanwu        Igbo Masquerades
# 87  Sère-en-Lavedan         Sere-en-Lavedan
# 88            Starz               Starzplay
#
#                                                 found  match
# 0   [Asarina scandens | A Growing Obsession, Hangi...  False
# 1   [Phet - Wikipedia, Kamphaeng Phet - Wikipedia,...   True
# 2   [Lincolnshire Police, ABPI LINC | Resource Sea...  False
# 3   [carter conboy Archives - Carter Conboy, Conbo...   True
# 4   [Mouths (Lat.) crossword clue - Crossword Quiz...   True
# ..                                                ...    ...
# 84  [Linda Sue  Beneigh - Chartiers Valley High Sc...   True
# 85  [Tarring - Wikipedia, Tarring, West Sussex - W...   True
# 86  [Igbo Masquerades  Catherine Onyemelukwe, Offa...   True
# 87  [Sere - Wikipedia, sere - Wiktionary, SERES - ...  False
# 88  [sam raimi - Search | STARZ PLAY, Starzplay | ...   True
#
# [89 rows x 4 columns]

# %%
not_matched = df[df.match == False].reset_index(drop=True)
not_matched
# Out:
#               title                                  alt_title  \
# 0     Kischinskinia                     Kischinskinia scandens
# 1            Alinja                                     Əlincə
# 2        bismuthine                                 Bismuthane
# 3            Yalvaç                                     Yalvac
# 4     Semiperimeter                             Semi-perimeter
# 5             Aglet                                      Agnet
# 6       Placentalia  Evolutionary history of placental mammals
# 7        Corectopia                          Corectopia in eye
# 8      Anthroponymy                                Anthroponym
# 9            Bulway                                    Buluwai
# 10     Febronianism                                  Febronian
# 11            Nizar                                      Nezar
# 12         Mešeišta    Mešeišta Opština, Republic of Macedonia
# 13    Barbarophryne                           Bufo brongersmai
# 14       Bjeloševac                                 Bjelosevac
# 15       autocannon                             Machine cannon
# 16           dulcin                                     Sucrol
# 17           Durtro                               Durtro Jnana
# 18          Örnäset                                    Ornaset
# 19     Vinstradalen                                 Vinstradal
# 20         Trzyciąż                                   Trzyciaz
# 21     Self-surgery                               Self surgery
# 22         Potštejn                         Potštýn nad Orlicí
# 23     Themistoclea                       Aristoclea of Delphi
# 24            Mokai                                Mōkai Marae
# 25            apsis                                      Apses
# 26     Scorpaenidae                                    Racasse
# 27           Pumori                                    Pumo Ri
# 28         Radohima                             Maja Radohimës
# 29          Arapuni                                     Pōhara
# 30   Cyclotridecane                                     C13H26
# 31          Świecko                                    Swiecko
# 32          CKVG-FM               106.5 FM Vegreville, Alberta
# 33      Pteridinium                        Pteridinium simplex
# 34            Šumná                                     Šumná
# 35            Mania                             Manic Episodes
# 36         Ploërmel                                   Ploermel
# 37          Pechina                           Pechina, Almeria
# 38           WebRTC            Object Real-time Communications
# 39  Sère-en-Lavedan                            Sere-en-Lavedan
#
#                                                 found  match
# 0   [Asarina scandens | A Growing Obsession, Hangi...  False
# 1   [Lincolnshire Police, ABPI LINC | Resource Sea...  False
# 2   [what is tris(fluoranyl)bismuthane - LookChemi...  False
# 3   [Yalvac Museum, Turkey (Antioch of Pisidia), S...  False
# 4   [Find the value of c in a triangle if the semi...  False
# 5   [Food and Fertilizer Technology Center, FFTC A...  False
# 6   [Skinny 'Shrew' Is Oldest True Mammal | Live S...  False
# 7   [Delhi doctors flag rise in eye-related proble...  False
# 8   [Anthroponym - OmegaWiki: Multilingual Diction...  False
# 9                               [Buluwai - Wikipedia]  False
# 10               [febronian - definition and meaning]  False
# 11  [Nezar AlSayyad - Wikipedia, Nezar-AlSayyad | ...  False
# 12  [Site Map - Republic of Macedonia - TripAdviso...  False
# 13  [Multimedia Gallery: photos and videos of Bufo...  False
# 14  [Bjelosevac Map | Bosnia and Herzegovina Googl...  False
# 15  [Home - Cannon Machine Inc., BRTC Student buil...  False
# 16                                           [Dulcin]  False
# 17  [DURTRO / JNANA  Old Europa Cafe, Jnana Saksha...  False
# 18                                [rnset - Wikipedia]  False
# 19                           [Vinstradal - Wikipedia]  False
# 20     [Trzyci - Wikipedia, Gmina Trzyci - Wikipedia]  False
# 21  [Wellside Surgery - Self Care, Abbey Road Surg...  False
# 22  [r nad Orlic - Wikipedia, ampach (st nad Orlic...  False
# 23  [Delphi TList of records - Stack Overflow, Whe...  False
# 24  [Visual Guide Update - Saelt-Marae (VC132) - T...  False
# 25  [APSE - Association of People Supporting Emplo...  False
# 26       [Racasse-Studio & Moyens du Bord Production]  False
# 27  [Pumo Ri | Khumbu, Nepal | Mountain Photograph...  False
# 28  [Maja, Kalu shine for Bordeaux against St Etie...  False
# 29  [Phara - Wikipedia, Phara - Music - HulkShare,...  False
# 30  [Tridecylene | Definition of Tridecylene by Me...  False
# 31  [Swiecko  PDF Magazines | Download free PDF ma...  False
# 32  [CJJJ-FM CJ 106.5 - listen live, Listen BN Mal...  False
# 33  [U.S. Residents Now Onramp Easily and Risk-Fre...  False
# 34  [University of Minnesota Twin Cities, Health S...  False
# 35  [manic episodes | DailyStrength, Manic Episode...  False
# 36  [Ploermel News, Features, Match Reports, Trans...  False
# 37  [Bodyboarding Almeria Andalusia Spain, Puerta ...  False
# 38  [W3C ORTC CG Meeting 10  November 20 2015 | OR...  False
# 39  [Sere - Wikipedia, sere - Wiktionary, SERES - ...  False

# %% [markdown]
# "Not found table" - terms that were not found by the web search used

# %%
# prepare url and headers
url = "https://contextualwebsearch-websearch-v1.p.rapidapi.com/api/Search/WebSearchAPI"
headers = {
    'x-rapidapi-host': "contextualwebsearch-websearch-v1.p.rapidapi.com",
    'x-rapidapi-key': "9805ad717fmsh887356c31eef1c7p1d4dfejsn31827afa9324"
    }
main_titles_single, alt_titles_single, found_single, matches_single, similarities_single = [], [], [], [], []
for i in range(100):
    # select main and alt title at random from index
    alt, title = choose_alt_and_title(index)
    # preprocess the titles (Disambiguations and simialr WIKI stuff may be present)
    title, alt = re.split('[#:(]', title)[0], re.split('[#:(]', alt)[0]
    # query the alt title in web search
    querystring = {"pageNumber":"1","q":alt,"autoCorrect":"false","pageSize":"50"}
    try:
        response = requests.request("GET", url, headers=headers, params=querystring)
        # parse found titles
        found_titles = parse_response(response)
        # Title found or not?
        title_found = True in [title in t for t in found_titles]
        #calculate titles similarity
        max_similarity = max(np.array([string_similar(t, title) for t in found_titles]))

        main_titles_single.append(title)
        alt_titles_single.append(alt)
        found_single.append(found_titles)
        matches_single.append(title_found)
        similarities_single.append(max_similarity)
    except:
        continue

# %%
matches_single = np.array(matches_single)
accuracy = len(matches_single[matches_single == True]) / len(matches_single)
accuracy
# Out:
# 0.3424657534246575

# %%
sum(similarities_single) / len(similarities_single)
# Out:
# 0.480825282924828

# %%
df_single = pd.DataFrame({'title': main_titles_single, 'alt_title': alt_titles_single, 'found': found_single, 'match': matches_single})
df_single
# Out:
#             title      alt_title  \
# 0            Luck        Luckily
# 1           COSBI          CoSBi
# 2        Maljević       Maljevic
# 3   Lightstreamer         Weswit
# 4         Karabas        Carabas
# ..            ...            ...
# 68           LBMS           Lbms
# 69    Dharanendra     Dharnendra
# 70        Kumbaya     Kum-Ba-Yah
# 71       Linchpin       Lynchpin
# 72     Xōchipilli  MacuilxOchitl
#
#                                                 found  match
# 0   [luckily - Wiktionary, Luckily | Define Luckil...   True
# 1   [COSBI - Wikipedia, Cosbi | rabbisylviarothsch...   True
# 2   [Maljevic Map | Serbia and Montenegro Google S...  False
# 3   [Giant iGaming Firm Wirex Joins Forces with We...   True
# 4   [Carabas   Blog Archive    Events Profile: Pop...  False
# ..                                                ...    ...
# 68  [US LBM Holdings, LLC - Home, US LBM Holdings,...   True
# 69  [Products | Dharnendra Enterprise in Ahmedabad...  False
# 70  [Shipping & Returns - Kumbayah, Kum ba yah  Jo...   True
# 71  [Lynchpin | Analytics Consultancy, Company | L...  False
# 72  [Macuilxochitl - JPop.com, Macuilxochitl, Tlay...  False
#
# [73 rows x 4 columns]

# %% [markdown]
# In the end it really seems that we have suboptimal web search tool, since if we search manualy using google we get much more accurate results. We have to accept this fact though, as there is not a better alternative and state that we achieved around 50% accuracy and around 50% similarity betweeen phrases we searched for and the ones we found.

# %% [markdown]
# **Below are provided couple of examples used as a proof of the web search suboptimality. These are all taken from the 'not found table' and searched for with google.**

# %% [markdown]
# - Simplified Memory-Bounded A* - https://www.google.com/search?q=Simplified+Memory-Bounded+A*&oq=Simplified+Memory-Bounded+A*&aqs=chrome..69i57&sourceid=chrome&ie=UTF-8
# - Chyormozskoye Urban Settlement - https://www.google.com/search?q=Chyormozskoye+Urban+Settlement&oq=Chyormozskoye+Urban+Settlement&aqs=chrome..69i57&sourceid=chrome&ie=UTF-8
# - Tectonostratigraphic - https://www.google.com/search?q=Tectonostratigraphic&oq=Tectonostratigraphic&aqs=chrome..69i57&sourceid=chrome&ie=UTF-8
# - Mansôa, Guinea-Bissau - https://www.google.com/search?q=Mans%C3%B4a%2C+Guinea-Bissau&oq=Mans%C3%B4a%2C+Guinea-Bissau&aqs=chrome..69i57&sourceid=chrome&ie=UTF-8
# - Dediyapada - https://www.google.com/search?q=Dediyapada&oq=Dediyapada&aqs=chrome..69i57&sourceid=chrome&ie=UTF-8
